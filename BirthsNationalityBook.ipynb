# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
def getCSV():
    dfl = pd.read_csv(r'C:\Users\Tom\OneDrive\Documents\APROJECTS\BirthsNationality.csv')
    return dfl
df = getCSV() 
print(df)
print(set(list(df['Nationality'])))
# Out:
#            Statistic Label Quarter  \
# 0        Births Registered  2022Q1
# 1        Births Registered  2022Q1
# 2        Births Registered  2022Q1
# 3        Births Registered  2022Q1
# 4        Births Registered  2022Q1
# ..                     ...     ...
# 534  Average Age of Mother  2024Q3
# 535  Average Age of Mother  2024Q3
# 536  Average Age of Mother  2024Q3
# 537  Average Age of Mother  2024Q3
# 538  Average Age of Mother  2024Q3
#
#                                            Nationality    UNIT    VALUE
# 0    EU14 excl Irl (countries in the EU pre 2004 ex...  Number    359.0
# 1    EU15 to EU27 (accession countries joined post ...  Number   1359.0
# 2                                                Irish  Number  12508.0
# 3                              Other nationalities (7)  Number   1580.0
# 4                                                   UK  Number    325.0
# ..                                                 ...     ...      ...
# ...

# %%
label='Births Registered'
filtered_df = df[df['Statistic Label']==label]
filtered_df = filtered_df[filtered_df['Nationality']!='All nationalities']

print(filtered_df)
# Out:
#       Statistic Label Quarter  \
# 0   Births Registered  2022Q1
# 1   Births Registered  2022Q1
# 2   Births Registered  2022Q1
# 3   Births Registered  2022Q1
# 4   Births Registered  2022Q1
# ..                ...     ...
# 71  Births Registered  2024Q3
# 72  Births Registered  2024Q3
# 73  Births Registered  2024Q3
# 74  Births Registered  2024Q3
# 75  Births Registered  2024Q3
#
#                                           Nationality    UNIT    VALUE
# 0   EU14 excl Irl (countries in the EU pre 2004 ex...  Number    359.0
# 1   EU15 to EU27 (accession countries joined post ...  Number   1359.0
# 2                                               Irish  Number  12508.0
# 3                             Other nationalities (7)  Number   1580.0
# 4                                                  UK  Number    325.0
# ..                                                ...     ...      ...
# 71  EU15 to EU27 (accession countries joined post ...  Number    911.0
# ...
